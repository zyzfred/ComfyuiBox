# %%
import sys
import os
sys.path.append("/data/user/zhaoyizhe/projects/ysp/comfyui-box")
import logging
from app.comfyui.workflow import *

# %%
workflow_loader.reload_workflows()

# %%
workflow_config_loader.load_all_configs
# Out:
# <bound method ConfigLoader.load_all_configs of <app.comfyui.workflow.ConfigLoader object at 0x7f0595bfe820>>

# %%
workflow_config_loader.configs
# Out:
# {'多角度特写': {'workflow_name': '多角度特写工作流',
#   'input_mappings': [{'node_id': '44',
#     'input_field': 'image',
#     'user_input_key': '文本',
#     'data_type': 'str',
#     'required': True,
#     'default_value': '',
#     'description': '文件在ComfyUI服务器的绝对路径'}]},
#  '故事生成': {'workflow_name': '故事生成工作流',
#   'input_mappings': [{'node_id': '5',
#     'input_field': 'prompt',
#     'user_input_key': '文本',
#     'data_type': 'str',
#     'required': True,
#     'default_value': '',
#     'description': '角色描述文本输入'},
#    {'node_id': '6',
#     'input_field': 'prompt',
#     'user_input_key': '文本',
#     'data_type': 'str',
#     'required': True,
#     'default_value': '默认提示词',
#     'description': '角色描述文本输入'},
#    {'node_id': '7',
#     'input_field': 'prompt',
#     'user_input_key': '文本',
#     'data_type': 'str',
#     'required': True,
#     'default_value': '默认提示词',
#     'description': '角色描述文本输入'},
#    {'node_id': '8',
#     'input_field': 'prompt',
#     'user_input_key': '文本',
# ...

# %%
workflow_loader.workflows
# Out:
# {'多角度特写': {'6': {'inputs': {'text': '((masterpiece, photo, best quality)), award winning, 4k, 8k, a character sheet, multiple views from different angles, looking in different directions, visible face, (white background:1.3)',
#     'clip': ['11', 0]},
#    'class_type': 'CLIPTextEncode'},
#   '8': {'inputs': {'samples': ['13', 0], 'vae': ['63', 0]},
#    'class_type': 'VAEDecode'},
#   '9': {'inputs': {'filename_prefix': 'ComfyUI', 'images': ['8', 0]},
#    'class_type': 'SaveImage'},
#   '11': {'inputs': {'clip_name1': 'clip_l.safetensors',
#     'clip_name2': 't5xxl_fp8_e4m3fn.safetensors',
#     'type': 'flux'},
#    'class_type': 'DualCLIPLoader'},
#   '13': {'inputs': {'noise': ['25', 0],
#     'guider': ['22', 0],
#     'sampler': ['16', 0],
#     'sigmas': ['17', 0],
#     'latent_image': ['118', 0]},
#    'class_type': 'SamplerCustomAdvanced'},
#   '16': {'inputs': {'sampler_name': 'deis'}, 'class_type': 'KSamplerSelect'},
#   '17': {'inputs': {'scheduler': 'beta',
# ...
